# %%
nu0 = 384228115.203e6
nu_mot2D = lambda nu_opll : 384229418.37e6 - 16*nu_opll

detuning = lambda nu_opll : nu_mot2D(nu_opll) - nu0

detuning(nu_opll = 82.22e6)

# Detuning to gamma: detuning / 6.067e6
# Out:
# -2.036096917751772

# %%
desired_detuning = 25e6
desired_nu_mot2D = desired_detuning + nu0

desired_nu_opll = (384229418.37e6 - desired_nu_mot2D) / 16

print(desired_nu_opll / 1e6)
# Out:
# 79.8854375
